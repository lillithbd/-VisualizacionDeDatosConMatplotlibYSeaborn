# %% [markdown]
# ### Importar librerías

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Crear Variables Categóricas

# %%
countries = ['INDIA', 'JAPAN', 'MEXICO', 'COLOMBIA', 'GERMANY']
population = [5000, 800, 900, 1000, 300]

# %% [markdown]
# ### Gráfica de Barras

# %%
plt.bar(countries, population)
plt.show()

# %% [markdown]
# ### Modificar colores y tamaño

# %%
plt.bar(countries,population,  width=0.5, color= ['aqua', 'grey', 'teal', 'crimson', 'violet'])
plt.show()

# %% [markdown]
# ### Modificar nombres en variables del eje X

# %%
plt.bar(countries,population,  width=0.5, color= ['aqua', 'grey', 'teal', 'crimson', 'violet'])
plt.xticks(np.arange(5), ('India', 'Japon', 'México', 'Colombia', 'Alemania'), rotation=45)
plt.show()

# %% [markdown]
# ### Crear un gráfico de manera horizontal

# %%
plt.barh(countries,population)
plt.show()

# %% [markdown]
# ### Reto

# %%
plt.bar(countries, population, width=0.5)
plt.title('Population por country \n(Non realistic values)')
plt.ylabel('Populations (Millions)')
plt.xlabel('Countries')
plt.xticks(np.arange(6), ('INDIA','JAPAN', 'MEXICO', 'COLOMBIA', 'USA', 'GERMANY'))
plt.legend(frameon=False)
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
