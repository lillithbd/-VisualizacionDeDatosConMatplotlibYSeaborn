# %% [markdown]
# ### Importando librerías

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Creando gráficas de barplot

# %%
sns.barplot(x=['A','B','C'], y = [1,3,2])
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %% [markdown]
# ### Comando Set para configurar fuentes y estilos

# %%
sns.set(style='darkgrid')
sns.barplot(x=['A','B','C'], y = [1,3,2])
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
sns.set(style='dark')
sns.barplot(x=['A','B','C'], y = [1,3,2])
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
sns.set(style='dark', palette='dark')
sns.barplot(x=['A','B','C'], y = [1,3,2])
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)

# %%
sns.set(style='dark', palette='dark', font="Verdana", font_scale=1)
sns.barplot(x=['A','B','C'], y = [1,3,2])
plt.show()
# Out:
# C:\Users\Asus\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1765: FutureWarning: unique with argument that is not not a Series, Index, ExtensionArray, or np.ndarray is deprecated and will raise in a future version.
#   order = pd.unique(vector)
