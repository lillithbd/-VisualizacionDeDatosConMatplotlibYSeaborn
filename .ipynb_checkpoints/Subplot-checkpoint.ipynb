# %% [markdown]
# ### Importar librerías

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ### Crear Set de Datos

# %%
x = np.linspace(0,5,11)
y = x ** 2

# %% [markdown]
# ### Subplot

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r--')
plt.subplot(1,2,2)
plt.hist(y)
plt.show()

# %% [markdown]
# ### Agregar diferentes Plots al gráfico

# %%
plt.subplot(1,2,1)
plt.plot(x,y, 'r--') # Plot 1
plt.plot(y,x, 'b:') #Plot 2

plt.subplot(1,2,2)
plt.pie(y)
plt.show()

# %% [markdown]
# ### Invertir la matriz de los gráficos

# %%
plt.subplot(2,1,1) #Grafico 1
plt.plot(x,y,'r--') #Plot 1
plt.plot(y,x,'b:')  #Plot 2

plt.subplot(2,1,2) #Grafico 2
plt.pie(y)         #Plot 1  
plt.show()
